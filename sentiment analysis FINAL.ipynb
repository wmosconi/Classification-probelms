# %%
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import intake
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import nltk

# %%
print(type(stopwords))
# Out:
# <class 'nltk.corpus.util.LazyCorpusLoader'>

# %%
f = open("/Users/williammosconiii/Desktop/sentiment-labelled-sentences/imdb_labelled.txt", 'r')
data = []
for line in f:
    line = line.replace('\n', '').strip().replace('\t', '')
    line = line.replace('?', '')
    line = line.replace('!', '')
    line = line.replace('.', '')
    line = line.replace('-', '')
    line = line.replace("'", '')
    line = line.replace(',', '')
    line = line.replace('"', '')
    line = line.replace(')', '')
    line = line.replace('(', '')
    line = line.replace(':', '')
    line = line.replace(';', '')
    data.append({'Review':line[:-1], 'Sentiment':line[-1:]})

# %%
df = pd.DataFrame.from_dict(data)
pd.set_option('display.max_colwidth', -1)
df
# Out:
#                                                                                                                                                                                       Review  \
# 0    A very very very slowmoving aimless movie about a distressed drifting young man
# 1    Not sure who was more lost  the flat characters or the audience nearly half of whom walked out
# 2    Attempting artiness with black & white and clever camera angles the movie disappointed  became even more ridiculous  as the acting was poor and the plot and lines almost nonexistent
# 3    Very little music or anything to speak of
# 4    The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head
# 5    The rest of the movie lacks art charm meaning If its about emptiness it works I guess because its empty
# 6    Wasted two hours
# 7    Saw the movie today and thought it was a good effort good messages for kids
# 8    A bit predictable
# ...

# %%
stopwords = set(stopwords.words('english'))
wordlist = []
for reviews in df.Review:
    tokens = [w.lower() for w in word_tokenize(reviews)]
    words = [w for w in tokens if w.isalnum() and w not in stopwords]
    wordlist.append(words)
df['words'] = wordlist
df
# Out:
#                                                                                                                                                                                       Review  \
# 0    A very very very slowmoving aimless movie about a distressed drifting young man
# 1    Not sure who was more lost  the flat characters or the audience nearly half of whom walked out
# 2    Attempting artiness with black & white and clever camera angles the movie disappointed  became even more ridiculous  as the acting was poor and the plot and lines almost nonexistent
# 3    Very little music or anything to speak of
# 4    The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head
# 5    The rest of the movie lacks art charm meaning If its about emptiness it works I guess because its empty
# 6    Wasted two hours
# 7    Saw the movie today and thought it was a good effort good messages for kids
# 8    A bit predictable
# ...

# %%
stemmedwords = []
for results in wordlist:
    swords = [ps.stem(results) for results in wordlist]
    stemmedwords.append(swords)
stemmedwords
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-b3f07312b4ce> in <module>
#       1 stemmedwords = []
#       2 for results in wordlist:
# ----> 3     swords = [ps.stem(results) for results in wordlist]
#       4     stemmedwords.append(swords)
#       5 stemmedwords
#
# <ipython-input-29-b3f07312b4ce> in <listcomp>(.0)
#       1 stemmedwords = []
#       2 for results in wordlist:
# ----> 3     swords = [ps.stem(results) for results in wordlist]
#       4     stemmedwords.append(swords)
#       5 stemmedwords
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nltk/stem/porter.py in stem(self, word)
#     654
#     655     def stem(self, word):
# --> 656         stem = word.lower()
#     657
#     658         if self.mode == self.NLTK_EXTENSIONS and word in self.pool:
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
# Out:
#                                                                                                                                                                                       Review  \
# 0    A very very very slowmoving aimless movie about a distressed drifting young man
# 1    Not sure who was more lost  the flat characters or the audience nearly half of whom walked out
# 2    Attempting artiness with black & white and clever camera angles the movie disappointed  became even more ridiculous  as the acting was poor and the plot and lines almost nonexistent
# 3    Very little music or anything to speak of
# 4    The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head
# 5    The rest of the movie lacks art charm meaning If its about emptiness it works I guess because its empty
# 6    Wasted two hours
# 7    Saw the movie today and thought it was a good effort good messages for kids
# 8    A bit predictable
# ...
